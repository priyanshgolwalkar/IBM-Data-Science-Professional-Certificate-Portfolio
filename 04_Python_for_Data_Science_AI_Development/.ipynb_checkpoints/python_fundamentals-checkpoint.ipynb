# %% [markdown]
# # Python for Data Science, AI & Development
#
# This notebook demonstrates core Python fundamentals required for data science including data types, control structures, functions, NumPy, and Pandas.

# %% [markdown]
# # Variables and Data Types

# %%
name = "Priyansh"
age = 21
gpa = 8.74
is_student = True

print(type(name))
print(type(age))
print(type(gpa))
print(type(is_student))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %% [markdown]
# # List Example

# %%
marks = [85, 90, 78, 88]
print("Marks:", marks)
# Out:
# Marks: [85, 90, 78, 88]

# %% [markdown]
# # Dictionary Example

# %%
student = {
    "Name": "Priyansh",
    "Branch": "CSE",
    "Year": 3
}

print("Student Info:", student)
# Out:
# Student Info: {'Name': 'Priyansh', 'Branch': 'CSE', 'Year': 3}

# %% [markdown]
# # Loop Example

# %%
for mark in marks:
    print("Mark:", mark)
# Out:
# Mark: 85
# Mark: 90
# Mark: 78
# Mark: 88

# %% [markdown]
# # Conditional Example

# %%
average = sum(marks) / len(marks)

if average >= 80:
    print("Performance: Excellent")
else:
    print("Performance: Needs Improvement")
# Out:
# Performance: Excellent

# %% [markdown]
# # Function

# %%
def calculate_average(numbers):
    return sum(numbers) / len(numbers)

print("Average Marks:", calculate_average(marks))
# Out:
# Average Marks: 85.25

# %% [markdown]
# # NumPy

# %%
import numpy as np

array = np.array([1, 2, 3, 4, 5])
print("Array:", array)
print("Mean:", np.mean(array))
print("Standard Deviation:", np.std(array))
# Out:
# Array: [1 2 3 4 5]
# Mean: 3.0
# Standard Deviation: 1.4142135623730951

# %% [markdown]
# # Pandas

# %%
import pandas as pd

data = {
    "Name": ["A", "B", "C"],
    "Score": [85, 90, 78]
}

df = pd.DataFrame(data)

print(df)
print("Average Score:", df["Score"].mean())
# Out:
#   Name  Score
# 0    A     85
# 1    B     90
# 2    C     78
# Average Score: 84.33333333333333

# %% [markdown]
# ## Conclusion
#
# This notebook demonstrates foundational Python skills required for data science including data structures, functions, NumPy operations, and Pandas DataFrame handling.
